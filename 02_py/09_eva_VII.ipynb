# %% [markdown]
# <h1 style="color: #00BFFF;">00 |</h1>

# %%
# 📚 Basic libraries
import os # file access
import matplotlib.pyplot as plt #  visualization
import numpy as np # image numeric array manipulation
import shutil # folder operations
import random # shuffle data

# ⚙️ Settings
import warnings # who likes warnings?
warnings.filterwarnings('ignore') # ignore warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # ignoring AVX warning from tensorflow

# 🌐 Computer Vision
import cv2 # image reading
from tensorflow import keras # deep learning and neural networks
from tensorflow.keras.preprocessing.image import ImageDataGenerator # data augmentation
from tensorflow.keras.utils import img_to_array, array_to_img, load_img # saving augmented Data
from tensorflow.keras import layers, Model # neural network and model
from keras.models import load_model

# %%
# 🎯 Specific Functions
def augment_images(data_dir, datagen, num_images=5):
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpeg"):
            img_path = os.path.join(data_dir, filename)
            img_array = img_to_array(load_img(img_path))  # converting the image to numpy array
            img_array = img_array.reshape((1,) + img_array.shape)  # reshape the data

            # Generate new images
            for i, _ in enumerate(datagen.flow(img_array, batch_size=1, save_to_dir=data_dir, save_prefix='aug', save_format='jpeg')):
                if i >= num_images - 1:
                    break
                    
def unet_model(input_shape):
    inputs = layers.Input(shape=input_shape)

    # downsampling
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    residual_1 = x
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    residual_2 = x  # Capture the residual before pooling
    x = layers.MaxPooling2D((2, 2))(x)

    # bottleneck
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)

    # upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.add([x, residual_2])

    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.add([x, residual_1])

    # output layer
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(x)

    return Model(inputs, outputs)

# %% [markdown]
# <h1 style="color: #00BFFF;">01 | Data Extraction</h1>

# %% [markdown]
# This public hand dataset contains different folders (numeric) with two subfolders: no_bg and original.
#
# The goal is to segment hands from unseen data with high precision.

# %%
data_path = os.path.join(os.path.expanduser("~"), "Documents", "1_projects", "01_hands", "01_data")

# %% [markdown]
# <h1 style="color: #00BFFF;">02 | Data Cleaning</h1>

# %% [markdown]
# For full Data Cleaning Process documentation, refer to 02_new_prototype python script.

# %%
# folders for clean images:
original_clean_path = os.path.join(data_path, '00_original_clean')
no_bg_clean_path = os.path.join(data_path, '00_no_bg_clean')

# %% [markdown]
# <h3 style="color: #008080;">Training, Validation and Test</h3>

# %%
# original and mask directories for test
test_dir = os.path.join(data_path, "03_test")

# original and mask directories for train and validation
train_dir = os.path.join(data_path, "01_train")
val_dir = os.path.join(data_path, "02_validation")

# %% [markdown]
# <h4 style="color: #008080;">Training, Validation and Test split</h3>

# %% [markdown]
# For this model, we use (as in 02_new_prototype python script):
# * 65% Data for Training (it'll be augmented)
# * 25% Data for Validation
# * 10% Data for Testing

# %% [markdown]
# <h3 style="color: #008080;">Debugging ImageDataGenerator</h3>

# %% [markdown]
# ImageDataGenerator wasn't detecting images. They need to be in subfolders.

# %%
train_original_dir = os.path.join(train_dir, "original")
train_mask_dir = os.path.join(train_dir, "mask")

val_original_dir = os.path.join(val_dir, "original")
val_mask_dir = os.path.join(val_dir, "mask")

test_original_dir = os.path.join(test_dir, "original")
test_mask_dir = os.path.join(test_dir, "mask")

# %% [markdown]
# <h1 style="color: #00BFFF;">03 | Data Pre-Processing</h1>

# %% [markdown]
# <h3 style="color: #008080;">Pre-Processing</h3>

# %%
train_image_datagen = ImageDataGenerator(rescale=1./255)
train_mask_datagen = ImageDataGenerator(rescale=1./255)

val_image_datagen = ImageDataGenerator(rescale=1./255)
val_mask_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# <h2 style="color: #00BFFF;">Data Augmentation</h3>

# %% [markdown]
# For full Data Augmentation process, refer to 02_new_protype python script

# %% [markdown]
# <h1 style="color: #00BFFF;">04 | Modeling</h1>

# %% [markdown]
# <h3 style="color: #008080;">Fine-Tunning the Model</h3>

# %%
# Parameters that we can fine-tune later on
img_height = 480
img_width = 272
image_size = (img_height, img_width)
batch_size = 8

# %% [markdown]
# <h3 style="color: #008080;">Train and Validation Data</h3>

# %%
train_image_gen = train_image_datagen.flow_from_directory(
    train_original_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

train_mask_gen = train_mask_datagen.flow_from_directory(
    train_mask_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="grayscale",
    shuffle=False
)
# Out:
# Found 303 images belonging to 1 classes.
# Found 303 images belonging to 1 classes.

# %%
X_train = zip(train_image_gen, train_mask_gen)

# %%
val_image_gen = val_image_datagen.flow_from_directory(
    val_original_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

val_mask_gen = val_mask_datagen.flow_from_directory(
    val_mask_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="grayscale",
    shuffle=False
)
# Out:
# Found 19 images belonging to 1 classes.
# Found 19 images belonging to 1 classes.

# %%
x_val = zip(val_image_gen, val_mask_gen)

# %% [markdown]
# <h3 style="color: #008080;">Model Selection</h3>

# %%
model = unet_model(input_shape=(img_height, img_width, 3))

# %% [markdown]
# <h3 style="color: #008080;">Hyperparameters</h3>

# %% [markdown]
# <h3 style="color: #008080;">Hyperparameters</h3>

# %%
model.compile(
    optimizer=keras.optimizers.Adamax(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy", keras.metrics.MeanIoU(num_classes=2)]
)

# %% [markdown]
# <h3 style="color: #008080;">Epochs</h3>

# %%
X_train_steps = len(train_image_gen)
x_val_steps = len(val_image_gen)

epochs = 30

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,  # my patience for this
    verbose=1,
    restore_best_weights=True 
)

# %% [markdown]
# <h3 style="color: #008080;">Check Points</h3>

# %%
checkpoints = os.path.join(data_path, "04_epochs", "eva_VII_{epoch}.keras")

callbacks = [
    keras.callbacks.ModelCheckpoint(checkpoints),
    early_stopping
]

# %% [markdown]
# <h3 style="color: #008080;">Deep Learning</h3>

# %%
history = model.fit(
    x=X_train,
    epochs=epochs, 
    steps_per_epoch=X_train_steps,
    validation_data=x_val,
    validation_steps=x_val_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 38/38 [==============================] - 718s 19s/step - loss: 0.7420 - accuracy: 0.5798 - mean_io_u: 0.3835 - val_loss: 0.6034 - val_accuracy: 0.7298 - val_mean_io_u: 0.3676
# Epoch 2/30
# 38/38 [==============================] - 683s 18s/step - loss: 0.6367 - accuracy: 0.6656 - mean_io_u: 0.3835 - val_loss: 0.5749 - val_accuracy: 0.7298 - val_mean_io_u: 0.3676
# Epoch 3/30
# 38/38 [==============================] - 674s 18s/step - loss: 0.5955 - accuracy: 0.7026 - mean_io_u: 0.3835 - val_loss: 0.5694 - val_accuracy: 0.7298 - val_mean_io_u: 0.3676
# Epoch 4/30
# 38/38 [==============================] - 682s 18s/step - loss: 0.5783 - accuracy: 0.7182 - mean_io_u: 0.3835 - val_loss: 0.5674 - val_accuracy: 0.7298 - val_mean_io_u: 0.3676
# Epoch 5/30
# 38/38 [==============================] - 687s 18s/step - loss: 0.5674 - accuracy: 0.7273 - mean_io_u: 0.3835 - val_loss: 0.5635 - val_accuracy: 0.7298 - val_mean_io_u: 0.3676
# Epoch 6/30
# 38/38 [==============================] - 692s 18s/step - loss: 0.5574 - accuracy: 0.7327 - mean_io_u: 0.3835 - val_loss: 0.5605 - val_accuracy: 0.7298 - val_mean_io_u: 0.3676
# Epoch 7/30
# 38/38 [==============================] - 664s 18s/step - loss: 0.5510 - accuracy: 0.7360 - mean_io_u: 0.3835 - val_loss: 0.5451 - val_accuracy: 0.7299 - val_mean_io_u: 0.3676
# Epoch 8/30
# 38/38 [==============================] - 671s 18s/step - loss: 0.5426 - accuracy: 0.7410 - mean_io_u: 0.3835 - val_loss: 0.5433 - val_accuracy: 0.7300 - val_mean_io_u: 0.3676
# Epoch 9/30
# 38/38 [==============================] - 680s 18s/step - loss: 0.5390 - accuracy: 0.7432 - mean_io_u: 0.3835 - val_loss: 0.5249 - val_accuracy: 0.7303 - val_mean_io_u: 0.3676
# Epoch 10/30
# 38/38 [==============================] - 682s 18s/step - loss: 0.5358 - accuracy: 0.7447 - mean_io_u: 0.3835 - val_loss: 0.5164 - val_accuracy: 0.7309 - val_mean_io_u: 0.3676
# Epoch 11/30
# 38/38 [==============================] - 690s 18s/step - loss: 0.5338 - accuracy: 0.7459 - mean_io_u: 0.3835 - val_loss: 0.5040 - val_accuracy: 0.7318 - val_mean_io_u: 0.3676
# Epoch 12/30
# 38/38 [==============================] - 668s 17s/step - loss: 0.5325 - accuracy: 0.7463 - mean_io_u: 0.3835 - val_loss: 0.4901 - val_accuracy: 0.7326 - val_mean_io_u: 0.3676
# Epoch 13/30
# 38/38 [==============================] - 696s 18s/step - loss: 0.5295 - accuracy: 0.7480 - mean_io_u: 0.3835 - val_loss: 0.4811 - val_accuracy: 0.7333 - val_mean_io_u: 0.3676
# Epoch 14/30
# 38/38 [==============================] - 703s 18s/step - loss: 0.5287 - accuracy: 0.7481 - mean_io_u: 0.3835 - val_loss: 0.4767 - val_accuracy: 0.7340 - val_mean_io_u: 0.3676
# Epoch 15/30
# 38/38 [==============================] - 706s 19s/step - loss: 0.5256 - accuracy: 0.7505 - mean_io_u: 0.3835 - val_loss: 0.4843 - val_accuracy: 0.7350 - val_mean_io_u: 0.3676
# Epoch 16/30
# 38/38 [==============================] - 691s 18s/step - loss: 0.5265 - accuracy: 0.7493 - mean_io_u: 0.3835 - val_loss: 0.4552 - val_accuracy: 0.7334 - val_mean_io_u: 0.3676
# Epoch 17/30
# 38/38 [==============================] - 697s 18s/step - loss: 0.5233 - accuracy: 0.7505 - mean_io_u: 0.3835 - val_loss: 0.4535 - val_accuracy: 0.7379 - val_mean_io_u: 0.3676
# Epoch 18/30
# 38/38 [==============================] - 709s 19s/step - loss: 0.5230 - accuracy: 0.7500 - mean_io_u: 0.3835 - val_loss: 0.4406 - val_accuracy: 0.7368 - val_mean_io_u: 0.3676
# Epoch 19/30
# 38/38 [==============================] - 691s 18s/step - loss: 0.5212 - accuracy: 0.7506 - mean_io_u: 0.3835 - val_loss: 0.4380 - val_accuracy: 0.7391 - val_mean_io_u: 0.3676
# Epoch 20/30
# 38/38 [==============================] - 689s 18s/step - loss: 0.5204 - accuracy: 0.7503 - mean_io_u: 0.3835 - val_loss: 0.4391 - val_accuracy: 0.7376 - val_mean_io_u: 0.3676
# Epoch 21/30
# 38/38 [==============================] - 692s 18s/step - loss: 0.5190 - accuracy: 0.7512 - mean_io_u: 0.3835 - val_loss: 0.4448 - val_accuracy: 0.7385 - val_mean_io_u: 0.3676
# Epoch 22/30
# 38/38 [==============================] - 711s 19s/step - loss: 0.5183 - accuracy: 0.7511 - mean_io_u: 0.3835 - val_loss: 0.4417 - val_accuracy: 0.7370 - val_mean_io_u: 0.3676
# Epoch 23/30
# 38/38 [==============================] - 710s 19s/step - loss: 0.5172 - accuracy: 0.7517 - mean_io_u: 0.3835 - val_loss: 0.4522 - val_accuracy: 0.7375 - val_mean_io_u: 0.3676
# Epoch 24/30
# 38/38 [==============================] - 683s 18s/step - loss: 0.5165 - accuracy: 0.7516 - mean_io_u: 0.3835 - val_loss: 0.4507 - val_accuracy: 0.7365 - val_mean_io_u: 0.3676
# Epoch 25/30
# 38/38 [==============================] - 681s 18s/step - loss: 0.5159 - accuracy: 0.7519 - mean_io_u: 0.3835 - val_loss: 0.4492 - val_accuracy: 0.7376 - val_mean_io_u: 0.3676
# Epoch 26/30
# 38/38 [==============================] - 663s 17s/step - loss: 0.5150 - accuracy: 0.7518 - mean_io_u: 0.3835 - val_loss: 0.4496 - val_accuracy: 0.7378 - val_mean_io_u: 0.3676
# Epoch 27/30
# 38/38 [==============================] - 683s 18s/step - loss: 0.5140 - accuracy: 0.7525 - mean_io_u: 0.3835 - val_loss: 0.4459 - val_accuracy: 0.7398 - val_mean_io_u: 0.3676
# Epoch 28/30
# 38/38 [==============================] - 681s 18s/step - loss: 0.5135 - accuracy: 0.7522 - mean_io_u: 0.3835 - val_loss: 0.4476 - val_accuracy: 0.7374 - val_mean_io_u: 0.3676
# Epoch 29/30
# 38/38 [==============================] - 681s 18s/step - loss: 0.5127 - accuracy: 0.7528 - mean_io_u: 0.3835 - val_loss: 0.4550 - val_accuracy: 0.7379 - val_mean_io_u: 0.3676
# Epoch 30/30
# 38/38 [==============================] - 686s 18s/step - loss: 0.5124 - accuracy: 0.7525 - mean_io_u: 0.3835 - val_loss: 0.4438 - val_accuracy: 0.7376 - val_mean_io_u: 0.3676

# %% [markdown]
# <h1 style="color: #00BFFF;">05 | Evaluating the Model</h1>

# %%
#  path to best epoch
checkpoint_path = os.path.join(data_path, "04_epochs", "eva_VII_30.keras")

# load the model
loaded_model = load_model(checkpoint_path)

# %%
test_image_datagen = ImageDataGenerator(rescale=1./255)
test_mask_datagen = ImageDataGenerator(rescale=1./255)

# %%
test_image_gen = test_image_datagen.flow_from_directory(
    test_original_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

test_mask_gen = test_mask_datagen.flow_from_directory(
    test_mask_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="grayscale",
    shuffle=False
)
# Out:
# Found 9 images belonging to 1 classes.
# Found 9 images belonging to 1 classes.

# %%
Y_test = zip(test_image_gen, test_mask_gen)

# %% [markdown]
# <h3 style="color: #008080;">Metrics</h3>

# %%
images, masks = next(Y_test)

# %% [markdown]
# # evaluating the model
# loss, accuracy, iou = loaded_model.evaluate(Y_test, steps=len(test_image_gen))
#
# print(f"Test Loss: {loss:.4f}")
# print(f"Test Accuracy: {accuracy:.4f}")
# print(f"Test MeanIoU: {iou:.4f}")

# %%
# predict masks using the model
predictions = loaded_model.predict(images)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
for i in range(len(images)):
    plt.figure(figsize=(15, 5))

    # Display original image
    plt.subplot(1, 4, 1)
    plt.imshow(images[i])
    plt.title('Original Image')

    # Display true mask
    plt.subplot(1, 4, 2)
    plt.imshow(masks[i].squeeze(), cmap='gray')
    plt.title('True Mask')

    # Display predicted mask
    plt.subplot(1, 4, 3)
    pred_mask_display = np.where(predictions[i].squeeze() > 0.5, 1, 0)
    plt.imshow(pred_mask_display, cmap='gray')
    plt.title('Predicted Mask')
    
    # Display segmented image
    plt.subplot(1, 4, 4)
    segmented_img = images[i] * pred_mask_display[:, :, np.newaxis]
    plt.imshow(segmented_img)
    plt.title('Segmented Image')
    
    plt.tight_layout()
    plt.show()
