# %% [markdown]
# <h1 style="color: #00BFFF;">00 |</h1>

# %%
# 📚 Basic libraries
import os # file access
import matplotlib.pyplot as plt #  visualization
import numpy as np # image numeric array manipulation
import shutil # folder operations
import random # shuffle data

# ⚙️ Settings
import warnings # who likes warnings?
warnings.filterwarnings('ignore') # ignore warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # ignoring AVX warning from tensorflow

# 🌐 Computer Vision
import cv2 # image reading
from tensorflow import keras # deep learning and neural networks
from tensorflow.keras.preprocessing.image import ImageDataGenerator # data augmentation
from tensorflow.keras.utils import img_to_array, array_to_img, load_img # saving augmented Data
from tensorflow.keras import layers, Model # neural network and model
from keras.models import load_model

# %%
# 🎯 Specific Functions
def augment_images(data_dir, datagen, num_images=5):
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpeg"):
            img_path = os.path.join(data_dir, filename)
            img_array = img_to_array(load_img(img_path))  # converting the image to numpy array
            img_array = img_array.reshape((1,) + img_array.shape)  # reshape the data

            # Generate new images
            for i, _ in enumerate(datagen.flow(img_array, batch_size=1, save_to_dir=data_dir, save_prefix='aug', save_format='jpeg')):
                if i >= num_images - 1:
                    break
                    
def unet_model(input_shape):
    inputs = layers.Input(shape=input_shape)

    # downsampling
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    residual_1 = x
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    residual_2 = x  # Capture the residual before pooling
    x = layers.MaxPooling2D((2, 2))(x)

    # bottleneck
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)

    # upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.add([x, residual_2])

    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.add([x, residual_1])

    # output layer
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(x)

    return Model(inputs, outputs)

# %% [markdown]
# <h1 style="color: #00BFFF;">01 | Data Extraction</h1>

# %% [markdown]
# This public hand dataset contains different folders (numeric) with two subfolders: no_bg and original.
#
# The goal is to segment hands from unseen data with high precision.

# %%
data_path = os.path.join(os.path.expanduser("~"), "Documents", "1_projects", "01_hands", "01_data")

# %% [markdown]
# <h1 style="color: #00BFFF;">02 | Data Cleaning</h1>

# %% [markdown]
# For full Data Cleaning Process documentation, refer to 02_new_prototype python script.

# %%
# folders for clean images:
original_clean_path = os.path.join(data_path, '00_original_clean')
no_bg_clean_path = os.path.join(data_path, '00_no_bg_clean')

# %% [markdown]
# <h3 style="color: #008080;">Training, Validation and Test</h3>

# %%
# original and mask directories for test
test_dir = os.path.join(data_path, "03_test")

# original and mask directories for train and validation
train_dir = os.path.join(data_path, "01_train")
val_dir = os.path.join(data_path, "02_validation")

# %% [markdown]
# <h4 style="color: #008080;">Training, Validation and Test split</h3>

# %% [markdown]
# For this model, we use (as in 02_new_prototype python script):
# * 65% Data for Training (it'll be augmented)
# * 25% Data for Validation
# * 10% Data for Testing

# %% [markdown]
# <h3 style="color: #008080;">Debugging ImageDataGenerator</h3>

# %% [markdown]
# ImageDataGenerator wasn't detecting images. They need to be in subfolders.

# %%
train_original_dir = os.path.join(train_dir, "original")
train_mask_dir = os.path.join(train_dir, "mask")

val_original_dir = os.path.join(val_dir, "original")
val_mask_dir = os.path.join(val_dir, "mask")

test_original_dir = os.path.join(test_dir, "original")
test_mask_dir = os.path.join(test_dir, "mask")

# %% [markdown]
# <h1 style="color: #00BFFF;">03 | Data Pre-Processing</h1>

# %% [markdown]
# <h3 style="color: #008080;">Noise Reduction</h3>

# %% [markdown]
# Bilateral Filtering:

# %%
def apply_denoising(img):
    # Bilateral Filtering
    bilateral = cv2.bilateralFilter(img, 9, 75, 75)
    return bilateral

# %% [markdown]
# <h3 style="color: #008080;">Histogram Equalization</h3>

# %% [markdown]
# CLAHE:

# %%
def enhance_contrast(img):
    # if the image is grayscale or not. If not, convert it.
    if len(img.shape) == 3 and img.shape[2] == 3:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    else:
        gray = img

    gray = np.uint8(gray)
    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)) # applying CLAHE
    clahe_img = clahe.apply(gray)
    
    return clahe_img

# %% [markdown]
# <h3 style="color: #008080;">All pre-processing methods:</h3>

# %%
def custom_preprocessing(img):
    bilateral_img = apply_denoising(img)
    enhance_contrast_img = enhance_contrast(bilateral_img)
    
    dilation_img_3ch = np.stack([enhance_contrast_img]*3, axis=-1) # single channel to a 3 channel image
    
    return dilation_img_3ch.astype(np.float32) # converting it as a float for rescaling

# %% [markdown]
# <h3 style="color: #008080;">Pre-Processing</h3>

# %%
train_image_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=custom_preprocessing)
train_mask_datagen = ImageDataGenerator(rescale=1./255)

val_image_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=custom_preprocessing)
val_mask_datagen = ImageDataGenerator(rescale=1./255)

test_image_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=custom_preprocessing)
test_mask_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# <h2 style="color: #00BFFF;">Data Augmentation</h3>

# %% [markdown]
# For full Data Augmentation process, refer to 02_new_protype python script

# %% [markdown]
# <h1 style="color: #00BFFF;">04 | Modeling</h1>

# %% [markdown]
# <h3 style="color: #008080;">Fine-Tunning the Model</h3>

# %%
# Parameters that we can fine-tune later on
img_height = 480
img_width = 272
image_size = (img_height, img_width)
batch_size = 8

# %% [markdown]
# <h3 style="color: #008080;">Train and Validation Data</h3>

# %%
train_image_gen = train_image_datagen.flow_from_directory(
    train_original_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

train_mask_gen = train_mask_datagen.flow_from_directory(
    train_mask_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="grayscale",
    shuffle=False
)
# Out:
# Found 303 images belonging to 1 classes.
# Found 303 images belonging to 1 classes.

# %%
X_train = zip(train_image_gen, train_mask_gen)

# %%
val_image_gen = val_image_datagen.flow_from_directory(
    val_original_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

val_mask_gen = val_mask_datagen.flow_from_directory(
    val_mask_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="grayscale",
    shuffle=False
)
# Out:
# Found 19 images belonging to 1 classes.
# Found 19 images belonging to 1 classes.

# %%
x_val = zip(val_image_gen, val_mask_gen)

# %% [markdown]
# <h3 style="color: #008080;">Model Selection</h3>

# %%
model = unet_model(input_shape=(img_height, img_width, 3))

# %% [markdown]
# <h3 style="color: #008080;">Hyperparameters</h3>

# %%
model.compile(
    optimizer=keras.optimizers.Adamax(learning_rate=0.01),
    loss="binary_crossentropy",
    metrics=["accuracy", keras.metrics.MeanIoU(num_classes=2)]
)

# %% [markdown]
# <h3 style="color: #008080;">Hyperparameters</h3>

# %%
model.compile(
    optimizer=keras.optimizers.Adamax(learning_rate=0.01),
    loss="binary_crossentropy",
    metrics=["accuracy", keras.metrics.MeanIoU(num_classes=2)]
)

# %% [markdown]
# <h3 style="color: #008080;">Epochs</h3>

# %%
X_train_steps = len(train_image_gen)
x_val_steps = len(val_image_gen)

epochs = 30

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,  # my patience for this
    verbose=1,
    restore_best_weights=True 
)

# %% [markdown]
# <h3 style="color: #008080;">Check Points</h3>

# %%
checkpoints = os.path.join(data_path, "04_epochs", "save_at_{epoch}.keras")

callbacks = [
    keras.callbacks.ModelCheckpoint(checkpoints),
    early_stopping
]

# %% [markdown]
# <h3 style="color: #008080;">Deep Learning</h3>

# %%
history = model.fit(
    x=X_train,
    epochs=epochs, 
    steps_per_epoch=X_train_steps,
    validation_data=x_val,
    validation_steps=x_val_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 38/38 [==============================] - 695s 18s/step - loss: 0.6500 - accuracy: 0.6990 - mean_io_u_5: 0.3835 - val_loss: 0.6190 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 2/30
# 38/38 [==============================] - 686s 18s/step - loss: 0.5787 - accuracy: 0.7456 - mean_io_u_5: 0.3835 - val_loss: 0.6297 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 3/30
# 38/38 [==============================] - 689s 18s/step - loss: 0.5713 - accuracy: 0.7472 - mean_io_u_5: 0.3835 - val_loss: 0.6530 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 4/30
# 38/38 [==============================] - 680s 18s/step - loss: 0.5657 - accuracy: 0.7491 - mean_io_u_5: 0.3835 - val_loss: 0.6514 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 5/30
# 38/38 [==============================] - 690s 18s/step - loss: 0.5600 - accuracy: 0.7509 - mean_io_u_5: 0.3835 - val_loss: 0.6455 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 6/30
# 38/38 [==============================] - 672s 18s/step - loss: 0.5565 - accuracy: 0.7519 - mean_io_u_5: 0.3835 - val_loss: 0.6201 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 7/30
# 38/38 [==============================] - 688s 18s/step - loss: 0.5527 - accuracy: 0.7529 - mean_io_u_5: 0.3835 - val_loss: 0.6058 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 8/30
# 38/38 [==============================] - 676s 18s/step - loss: 0.5514 - accuracy: 0.7537 - mean_io_u_5: 0.3835 - val_loss: 0.6008 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 9/30
# 38/38 [==============================] - 667s 17s/step - loss: 0.5495 - accuracy: 0.7545 - mean_io_u_5: 0.3835 - val_loss: 0.5823 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 10/30
# 38/38 [==============================] - 679s 18s/step - loss: 0.5476 - accuracy: 0.7549 - mean_io_u_5: 0.3835 - val_loss: 0.5908 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 11/30
# 38/38 [==============================] - 656s 17s/step - loss: 0.5456 - accuracy: 0.7551 - mean_io_u_5: 0.3835 - val_loss: 0.5723 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 12/30
# 38/38 [==============================] - 677s 18s/step - loss: 0.5427 - accuracy: 0.7555 - mean_io_u_5: 0.3835 - val_loss: 0.5612 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 13/30
# 38/38 [==============================] - 660s 17s/step - loss: 0.5406 - accuracy: 0.7555 - mean_io_u_5: 0.3835 - val_loss: 0.5821 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 14/30
# 38/38 [==============================] - 652s 17s/step - loss: 0.5391 - accuracy: 0.7556 - mean_io_u_5: 0.3835 - val_loss: 0.5745 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 15/30
# 38/38 [==============================] - 635s 17s/step - loss: 0.5398 - accuracy: 0.7557 - mean_io_u_5: 0.3835 - val_loss: 0.5680 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 16/30
# 38/38 [==============================] - 623s 16s/step - loss: 0.5398 - accuracy: 0.7558 - mean_io_u_5: 0.3835 - val_loss: 0.5709 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 17/30
# 38/38 [==============================] - 658s 17s/step - loss: 0.5380 - accuracy: 0.7560 - mean_io_u_5: 0.3835 - val_loss: 0.5633 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 18/30
# 38/38 [==============================] - 612s 16s/step - loss: 0.5365 - accuracy: 0.7561 - mean_io_u_5: 0.3835 - val_loss: 0.5739 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 19/30
# 38/38 [==============================] - 627s 16s/step - loss: 0.5346 - accuracy: 0.7561 - mean_io_u_5: 0.3835 - val_loss: 0.5694 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 20/30
# 38/38 [==============================] - 613s 16s/step - loss: 0.5344 - accuracy: 0.7561 - mean_io_u_5: 0.3835 - val_loss: 0.6232 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 21/30
# 38/38 [==============================] - 703s 18s/step - loss: 0.5339 - accuracy: 0.7562 - mean_io_u_5: 0.3835 - val_loss: 0.5909 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 22/30
# 38/38 [==============================] - ETA: 0s - loss: 0.5326 - accuracy: 0.7562 - mean_io_u_5: 0.3835 Restoring model weights from the end of the best epoch: 12.
# 38/38 [==============================] - 626s 16s/step - loss: 0.5326 - accuracy: 0.7562 - mean_io_u_5: 0.3835 - val_loss: 0.6126 - val_accuracy: 0.7298 - val_mean_io_u_5: 0.3676
# Epoch 22: early stopping

# %% [markdown]
# <h1 style="color: #00BFFF;">05 | Evaluating the Model</h1>

# %%
#  path to best epoch
checkpoint_path = os.path.join(data_path, "04_epochs", "save_at_12.keras")

# load the model
loaded_model = load_model(checkpoint_path)

# %%
test_image_gen = test_image_datagen.flow_from_directory(
    test_original_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

test_mask_gen = test_mask_datagen.flow_from_directory(
    test_mask_dir,
    class_mode=None,
    seed=1337,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="grayscale",
    shuffle=False
)
# Out:
# Found 9 images belonging to 1 classes.
# Found 9 images belonging to 1 classes.

# %%
Y_test = zip(test_image_gen, test_mask_gen)

# %% [markdown]
# <h3 style="color: #008080;">Metrics</h3>

# %%
# evaluating the model
loss, accuracy, iou = loaded_model.evaluate(Y_test, steps=len(test_image_gen))

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test MeanIoU: {iou:.4f}")
# Out:
# 2/2 [==============================] - 3s 376ms/step - loss: 0.5497 - accuracy: 0.7550 - mean_io_u_1: 0.3800
# Test Loss: 0.5497
# Test Accuracy: 0.7550
# Test MeanIoU: 0.3800

# %%
images, masks = next(Y_test)

# %%
# predict masks using the model
predictions = loaded_model.predict(images)
# Out:
# 1/1 [==============================] - 0s 483ms/step

# %%
for i in range(len(images)):
    plt.figure(figsize=(15, 5))

    # Display original image
    plt.subplot(1, 4, 1)
    plt.imshow(images[i])
    plt.title('Original Image')

    # Display true mask
    plt.subplot(1, 4, 2)
    plt.imshow(masks[i].squeeze(), cmap='gray')
    plt.title('True Mask')

    # Display predicted mask
    plt.subplot(1, 4, 3)
    plt.imshow(predictions[i].squeeze(), cmap='gray', vmin=0, vmax=1)  # Ensure values are between 0 and 1
    plt.title('Predicted Mask')
    
    # Display segmented image
    plt.subplot(1, 4, 4)
    segmented_image = images[i] * predictions[i].squeeze()[:, :, np.newaxis]
    plt.imshow(segmented_image)
    plt.title('Segmented Image')
    
    plt.tight_layout()
    plt.show()
